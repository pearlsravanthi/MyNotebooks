# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('D:\\Documents\\ML\\shell_dataset\\dataset\\train\\train\\train.csv')

# %%
df.shape
# Out:
# (527040, 17)

# %%
df = df.rename(columns={'Global CMP22 (vent/cor) [W/m^2]':'CMP22', 'Direct sNIP [W/m^2]':'sNIP', 'Azimuth Angle [degrees]':'Angle', 'Tower Dry Bulb Temp [deg C]':'dryBulbTemp', 'Tower Wet Bulb Temp [deg C]':'wetBulbTemp', 'Tower Dew Point Temp [deg C]':'dewPtTemp', 'Tower RH [%]':'RH', 'Total Cloud Cover [%]':'TCC', 'Peak Wind Speed @ 6ft [m/s]':'windSpeed', 'Station Pressure [mBar]':'pressure', 'Precipitation (Accumulated) [mm]':'rain', 'Snow Depth [cm]':'snowDepth', 'Albedo (CMP11)':'Albedo','Avg Wind Direction @ 6ft [deg from N]':'windDirection'})

# %%
df.columns
# Out:
# Index(['DATE (MM/DD)', 'MST', 'CMP22', 'sNIP', 'Angle', 'dryBulbTemp',
#        'wetBulbTemp', 'dewPtTemp', 'RH', 'TCC', 'windSpeed', 'windDirection',
#        'pressure', 'rain', 'snowDepth', 'Moisture', 'Albedo'],
#       dtype='object')

# %%
new_columnName = ['DATE (MM/DD)', 'MST', 'CMP22', 'sNIP', 'Angle', 'dryBulbTemp',
       'wetBulbTemp', 'dewPtTemp', 'RH', 'windSpeed', 'windDirection',
       'pressure', 'rain', 'snowDepth', 'Moisture', 'Albedo', 'TCC']
df = df.reindex(columns=new_columnName)
df.columns
# Out:
# Index(['DATE (MM/DD)', 'MST', 'CMP22', 'sNIP', 'Angle', 'dryBulbTemp',
#        'wetBulbTemp', 'dewPtTemp', 'RH', 'windSpeed', 'windDirection',
#        'pressure', 'rain', 'snowDepth', 'Moisture', 'Albedo', 'TCC'],
#       dtype='object')

# %%
nightData = df[df.TCC<=-1]

# %%
nightData.shape
# Out:
# (276309, 17)

# %%
df.columns
# Out:
# Index(['DATE (MM/DD)', 'MST', 'CMP22', 'sNIP', 'Angle', 'dryBulbTemp',
#        'wetBulbTemp', 'dewPtTemp', 'RH', 'TCC', 'windSpeed', 'windDirection',
#        'pressure', 'rain', 'snowDepth', 'Moisture', 'Albedo'],
#       dtype='object')

# %%
df[df.TCC > -1].count()
# Out:
# DATE (MM/DD)     250731
# MST              250731
# CMP22            250731
# sNIP             250731
# Angle            250731
# dryBulbTemp      250731
# wetBulbTemp      250731
# dewPtTemp        250731
# RH               250731
# windSpeed        250731
# windDirection    250731
# pressure         250731
# rain             250731
# snowDepth        250731
# Moisture         250731
# Albedo           250731
# TCC              250731
# dtype: int64

# %%
df = df[df.TCC > -1]

# %%
df.shape
# Out:
# (250731, 17)

# %%
df.head(5)
# Out:
#     DATE (MM/DD)    MST    CMP22      sNIP      Angle  dryBulbTemp  \
# 467          1/1  07:47  14.4935  0.079127  123.84491        6.933
# 468          1/1  07:48  16.5178 -0.034618  124.01096        6.793
# 469          1/1  07:49  18.6171 -0.153309  124.17734        6.674
# 470          1/1  07:50  20.5986 -0.143419  124.34405        6.646
# 471          1/1  07:51  22.4362 -0.079128  124.51110        6.676
#
#      wetBulbTemp  dewPtTemp     RH  windSpeed  windDirection  pressure  rain  \
# 467        1.403     -5.597  38.24        0.7          210.3   802.042   0.0
# 468        1.294     -5.606  38.58        0.7          232.2   801.948   0.0
# 469        1.260     -5.540  39.12        1.7          263.9   801.940   0.0
# 470        1.306     -5.494  39.35        2.2          277.5   801.927   0.0
# 471        1.316     -5.384  39.64        2.2          233.4   801.829   0.0
#
#      snowDepth  Moisture  Albedo  TCC
# 467      0.032       0.0  0.1951    6
# ...

# %%
df['time'] = df.apply(lambda x: (x['MST'].split(':')[0]*60)+(x['MST'].split(':')[1]), axis=1)
df.columns
# Out:
# Index(['DATE (MM/DD)', 'MST', 'CMP22', 'sNIP', 'Angle', 'dryBulbTemp',
#        'wetBulbTemp', 'dewPtTemp', 'RH', 'windSpeed', 'windDirection',
#        'pressure', 'rain', 'snowDepth', 'Moisture', 'Albedo', 'TCC', 'time'],
#       dtype='object')

# %%
x = df.MST.head(1)
y = int(str(x).split(" ")[4].split('\n')[0].split(':')[0])*60+int(str(x).split(" ")[4].split('\n')[0].split(':')[1])
y
# Out:
# 467

# %%
x
# Out:
# 467    07:47
# Name: MST, dtype: object

# %%
s = df['MST']
arr=[]
for index, val in s.items():
    arr.append((int(str(val).split(':')[0])*60) + (int(str(val).split(':')[1])))
df2 = df.assign(time = arr)

df2.shape
# Out:
# (250731, 18)

# %%
df2.head(2)
# Out:
#     DATE (MM/DD)    MST    CMP22      sNIP      Angle  dryBulbTemp  \
# 467          1/1  07:47  14.4935  0.079127  123.84491        6.933
# 468          1/1  07:48  16.5178 -0.034618  124.01096        6.793
#
#      wetBulbTemp  dewPtTemp     RH  windSpeed  windDirection  pressure  rain  \
# 467        1.403     -5.597  38.24        0.7          210.3   802.042   0.0
# 468        1.294     -5.606  38.58        0.7          232.2   801.948   0.0
#
#      snowDepth  Moisture  Albedo  TCC  time
# 467      0.032       0.0  0.1951    6   467
# 468      0.029       0.0  0.1867    8   468

# %%
new_columnName = ['DATE (MM/DD)', 'MST', 'time', 'CMP22', 'sNIP', 'Angle', 'dryBulbTemp',
       'wetBulbTemp', 'dewPtTemp', 'RH', 'windSpeed', 'windDirection',
       'pressure', 'rain', 'snowDepth', 'Moisture', 'Albedo', 'TCC']
df2 = df2.reindex(columns=new_columnName)
df2.head(2)
# Out:
#     DATE (MM/DD)    MST  time    CMP22      sNIP      Angle  dryBulbTemp  \
# 467          1/1  07:47   467  14.4935  0.079127  123.84491        6.933
# 468          1/1  07:48   468  16.5178 -0.034618  124.01096        6.793
#
#      wetBulbTemp  dewPtTemp     RH  windSpeed  windDirection  pressure  rain  \
# 467        1.403     -5.597  38.24        0.7          210.3   802.042   0.0
# 468        1.294     -5.606  38.58        0.7          232.2   801.948   0.0
#
#      snowDepth  Moisture  Albedo  TCC
# 467      0.032       0.0  0.1951    6
# 468      0.029       0.0  0.1867    8

# %%
new_columnName = ['DATE (MM/DD)', 'MST', 'time', 'CMP22', 'sNIP', 'Angle', 'dryBulbTemp',
       'wetBulbTemp', 'dewPtTemp', 'RH', 'windSpeed', 'windDirection',
       'pressure', 'rain', 'snowDepth', 'Moisture', 'Albedo', 'TCC', 'TCC_30min', 'TCC_60min','TCC_90min','TCC_120min']
df2 = df2.reindex(columns=new_columnName)
df2.tail(3)
# Out:
#        DATE (MM/DD)    MST  time    CMP22      sNIP      Angle  dryBulbTemp  \
# 526583        12/31  16:23   983  15.6230 -0.197509  236.45711        2.235
# 526584        12/31  16:24   984  14.5605 -0.202446  236.62235        2.245
# 526585        12/31  16:25   985  13.7140 -0.222196  236.78727        2.226
#
#         wetBulbTemp  dewPtTemp     RH     ...      pressure  rain  snowDepth  \
# 526583       -1.773     -7.973  43.24     ...       812.664   0.0      2.696
# 526584       -1.683     -7.683  44.32     ...       812.675   0.0      2.654
# 526585       -1.681     -7.581  44.78     ...       812.695   0.0      2.653
#
#         Moisture  Albedo  TCC  TCC_30min  TCC_60min  TCC_90min  TCC_120min
# 526583       0.0  0.2470    8        NaN        NaN        NaN         NaN
# 526584       0.0  0.2462    7        NaN        NaN        NaN         NaN
# 526585       0.0  0.2438    7        NaN        NaN        NaN         NaN
#
# [3 rows x 22 columns]

# %%
df3=df2
df3.head(5)
# Out:
#     DATE (MM/DD)    MST  time    CMP22      sNIP      Angle  dryBulbTemp  \
# 467          1/1  07:47   467  14.4935  0.079127  123.84491        6.933
# 468          1/1  07:48   468  16.5178 -0.034618  124.01096        6.793
# 469          1/1  07:49   469  18.6171 -0.153309  124.17734        6.674
# 470          1/1  07:50   470  20.5986 -0.143419  124.34405        6.646
# 471          1/1  07:51   471  22.4362 -0.079128  124.51110        6.676
#
#      wetBulbTemp  dewPtTemp     RH     ...      pressure  rain  snowDepth  \
# 467        1.403     -5.597  38.24     ...       802.042   0.0      0.032
# 468        1.294     -5.606  38.58     ...       801.948   0.0      0.029
# 469        1.260     -5.540  39.12     ...       801.940   0.0      0.173
# 470        1.306     -5.494  39.35     ...       801.927   0.0      0.144
# 471        1.316     -5.384  39.64     ...       801.829   0.0      0.355
#
#      Moisture  Albedo  TCC  TCC_30min  TCC_60min  TCC_90min  TCC_120min
# ...

# %%
df3.loc[467, 'TCC_30min'] = df3.loc[467+30,'TCC']

# %%
df3.head(5)
# Out:
#     DATE (MM/DD)    MST  time    CMP22      sNIP      Angle  dryBulbTemp  \
# 467          1/1  07:47   467  14.4935  0.079127  123.84491        6.933
# 468          1/1  07:48   468  16.5178 -0.034618  124.01096        6.793
# 469          1/1  07:49   469  18.6171 -0.153309  124.17734        6.674
# 470          1/1  07:50   470  20.5986 -0.143419  124.34405        6.646
# 471          1/1  07:51   471  22.4362 -0.079128  124.51110        6.676
#
#      wetBulbTemp  dewPtTemp     RH     ...      pressure  rain  snowDepth  \
# 467        1.403     -5.597  38.24     ...       802.042   0.0      0.032
# 468        1.294     -5.606  38.58     ...       801.948   0.0      0.029
# 469        1.260     -5.540  39.12     ...       801.940   0.0      0.173
# 470        1.306     -5.494  39.35     ...       801.927   0.0      0.144
# 471        1.316     -5.384  39.64     ...       801.829   0.0      0.355
#
#      Moisture  Albedo  TCC  TCC_30min  TCC_60min  TCC_90min  TCC_120min
# ...

# %%
for index, row in df.iterrows():
    try:
        df3.loc[index, 'TCC_30min'] = df3.loc[index+30,'TCC']
        df3.loc[index, 'TCC_60min'] = df3.loc[index+60,'TCC']
        df3.loc[index, 'TCC_90min'] = df3.loc[index+90,'TCC']
        df3.loc[index, 'TCC_120min'] = df3.loc[index+120,'TCC']
    except KeyError:
        pass

# %%
df3.head(2)
# Out:
#     DATE (MM/DD)    MST  time    CMP22      sNIP      Angle  dryBulbTemp  \
# 467          1/1  07:47   467  14.4935  0.079127  123.84491        6.933
# 468          1/1  07:48   468  16.5178 -0.034618  124.01096        6.793
#
#      wetBulbTemp  dewPtTemp     RH     ...      pressure  rain  snowDepth  \
# 467        1.403     -5.597  38.24     ...       802.042   0.0      0.032
# 468        1.294     -5.606  38.58     ...       801.948   0.0      0.029
#
#      Moisture  Albedo  TCC  TCC_30min  TCC_60min  TCC_90min  TCC_120min
# 467       0.0  0.1951    6       20.0       13.0       17.0        46.0
# 468       0.0  0.1867    8       19.0       15.0       14.0        52.0
#
# [2 rows x 22 columns]

# %%
df3.loc[860:900]
# Out:
#     DATE (MM/DD)    MST  time    CMP22     sNIP      Angle  dryBulbTemp  \
# 860          1/1  14:20   860  182.820   51.250  213.10140         9.99
# 861          1/1  14:21   861  278.063  348.522  213.31870        10.02
# 862          1/1  14:22   862  469.131  914.875  213.53552        10.18
# 863          1/1  14:23   863  455.829  909.476  213.75186        10.54
# 864          1/1  14:24   864  444.202  910.140  213.96773        10.85
# 865          1/1  14:25   865  431.434  910.312  214.18312        11.08
# 866          1/1  14:26   866  417.150  909.185  214.39804        11.36
# 867          1/1  14:27   867  402.741  908.088  214.61247        11.63
# 868          1/1  14:28   868  389.338  908.048  214.82644        11.81
# 869          1/1  14:29   869  378.266  907.152  215.03992        12.00
# 870          1/1  14:30   870  369.103  905.812  215.25293        12.08
# 871          1/1  14:31   871  361.685  904.543  215.46546        11.98
# ...

# %%
df3.shape
# Out:
# (250731, 22)

# %%
df4 = df3.dropna(subset=['TCC_30min', 'TCC_60min', 'TCC_90min', 'TCC_120min'], how='any')
df4.shape
# Out:
# (201627, 22)

# %%
df4.loc[860:900]
# Out:
#     DATE (MM/DD)    MST  time    CMP22     sNIP      Angle  dryBulbTemp  \
# 860          1/1  14:20   860  182.820   51.250  213.10140         9.99
# 861          1/1  14:21   861  278.063  348.522  213.31870        10.02
# 862          1/1  14:22   862  469.131  914.875  213.53552        10.18
# 863          1/1  14:23   863  455.829  909.476  213.75186        10.54
# 864          1/1  14:24   864  444.202  910.140  213.96773        10.85
# 865          1/1  14:25   865  431.434  910.312  214.18312        11.08
#
#      wetBulbTemp  dewPtTemp     RH     ...      pressure  rain  snowDepth  \
# 860        2.332     -7.868  25.52     ...       801.182   0.0      0.350
# 861        2.295     -7.805  25.61     ...       801.240   0.0      0.364
# 862        2.509     -7.391  26.27     ...       801.308   0.0      0.444
# 863        2.702     -7.398  25.63     ...       801.314   0.0      0.453
# 864        2.747     -7.753  24.34     ...       801.380   0.0      0.468
# ...

# %%
df5=df3
df5.head(2)
df5.shape
# Out:
# (250731, 22)

# %%
df5.fillna(-1)
# Out:
#        DATE (MM/DD)    MST  time    CMP22       sNIP      Angle  dryBulbTemp  \
# 467             1/1  07:47   467  14.4935   0.079127  123.84491        6.933
# 468             1/1  07:48   468  16.5178  -0.034618  124.01096        6.793
# 469             1/1  07:49   469  18.6171  -0.153309  124.17734        6.674
# 470             1/1  07:50   470  20.5986  -0.143419  124.34405        6.646
# 471             1/1  07:51   471  22.4362  -0.079128  124.51110        6.676
# 472             1/1  07:52   472  23.9323   0.034618  124.67847        6.928
# 473             1/1  07:53   473  24.9174   0.158256  124.84619        7.190
# 474             1/1  07:54   474  25.5693   0.365967  125.01424        7.642
# 475             1/1  07:55   475  25.8414   0.509386  125.18263        7.926
# 476             1/1  07:56   476  25.7414   0.519275  125.35136        8.010
# 477             1/1  07:57   477  25.6456   0.623130  125.52044        8.190
# ...

# %%
df6 = df4
df6 = df6.drop(['DATE (MM/DD)', 'MST'], axis=1)

# %%
df4.iloc[:, -4].values
# Out:
# array([20., 19., 17., ..., 47., 51., 54.])

# %%
X = df6.iloc[:, :-4].values
y1 = df6.iloc[:, -4].values
y2 = df6.iloc[:, -3].values
y3 = df6.iloc[:, -2].values
y4 = df6.iloc[:, -1].values

# %%
df6.head(2)
# Out:
#      time    CMP22      sNIP      Angle  dryBulbTemp  wetBulbTemp  dewPtTemp  \
# 467   467  14.4935  0.079127  123.84491        6.933        1.403     -5.597
# 468   468  16.5178 -0.034618  124.01096        6.793        1.294     -5.606
#
#         RH  windSpeed  windDirection  pressure  rain  snowDepth  Moisture  \
# 467  38.24        0.7          210.3   802.042   0.0      0.032       0.0
# 468  38.58        0.7          232.2   801.948   0.0      0.029       0.0
#
#      Albedo  TCC  TCC_30min  TCC_60min  TCC_90min  TCC_120min
# 467  0.1951    6       20.0       13.0       17.0        46.0
# 468  0.1867    8       19.0       15.0       14.0        52.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y1_train, y1_test = train_test_split(X, y1, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y1_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(regressor.intercept_)
# Out:
# 166.83341820569288

# %%
print(regressor.coef_)
# Out:
# [-3.26264859e-02  1.11544964e-02 -1.71739492e-02  8.82917534e-02
#   6.75201713e-01 -9.08149003e-01  6.67005590e-02  1.14547035e-01
#   8.75835196e-02 -8.42293285e-03 -1.83068947e-01 -1.00339569e-01
#  -4.41290516e-04  1.15991116e+00 -2.88003114e+00  7.67248902e-01]

# %%
y1_pred = regressor.predict(X_test)

# %%
df_res1 = pd.DataFrame({'Actual': y1_test, 'Predicted': y1_pred})
df_res1
# Out:
#        Actual  Predicted
# 0        19.0  19.885659
# 1        64.0  87.873494
# 2         8.0  10.671792
# 3        99.0  95.427632
# 4        90.0  71.645173
# 5        83.0  40.374482
# 6        99.0  97.397867
# 7        18.0  18.575673
# 8        64.0  38.464863
# 9         6.0  10.216690
# 10       12.0  23.509769
# 11       97.0  97.461404
# 12       91.0  88.068611
# 13       94.0  92.437649
# 14       87.0  83.366279
# 15       98.0  93.200086
# 16       38.0  26.843973
# 17       86.0  93.353919
# 18       65.0  63.130151
# 19       57.0  81.484786
# 20       55.0  57.222209
# 21       14.0  18.032860
# 22       16.0  24.625495
# 23       23.0  39.581775
# 24       19.0  27.023864
# 25       32.0  39.324304
# 26       58.0  47.143613
# 27       17.0  15.582729
# 28       10.0   9.299087
# 29       30.0  34.334728
# ...       ...        ...
# 40296    23.0  57.024359
# 40297    97.0  93.002569
# 40298    42.0  35.139689
# 40299    88.0  80.626896
# 40300    10.0  15.558896
# ...

# %%
df_res1.mad()
# Out:
# Actual       33.247035
# Predicted    30.065361
# dtype: float64

# %%
df_res1.mean()
# Out:
# Actual       50.022219
# Predicted    49.963805
# dtype: float64

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(df_res1.Actual, df_res1.Predicted)
# Out:
# 9.451738786184778

# %%
df_train = df_train.rename(columns={'Global CMP22 (vent/cor) [W/m^2]':'CMP22', 'Direct sNIP [W/m^2]':'sNIP', 'Azimuth Angle [degrees]':'Angle', 'Tower Dry Bulb Temp [deg C]':'dryBulbTemp', 'Tower Wet Bulb Temp [deg C]':'wetBulbTemp', 'Tower Dew Point Temp [deg C]':'dewPtTemp', 'Tower RH [%]':'RH', 'Total Cloud Cover [%]':'TCC', 'Peak Wind Speed @ 6ft [m/s]':'windSpeed', 'Station Pressure [mBar]':'pressure', 'Precipitation (Accumulated) [mm]':'rain', 'Snow Depth [cm]':'snowDepth', 'Albedo (CMP11)':'Albedo','Avg Wind Direction @ 6ft [deg from N]':'windDirection'})

# %%
path = "D:\\Documents\\ML\\shell_dataset\\dataset\\test\\test\\"

# print(df6.columns)
X = df6.iloc[:, :-4].values
y1 = df6.iloc[:, -4].values
y2 = df6.iloc[:, -3].values
y3 = df6.iloc[:, -2].values
y4 = df6.iloc[:, -1].values
from sklearn.linear_model import LinearRegression
regressor1 = LinearRegression()
regressor2 = LinearRegression()
regressor3 = LinearRegression()
regressor4 = LinearRegression()


regressor1.fit(X, y1)
regressor2.fit(X, y2)
regressor3.fit(X, y3)
regressor4.fit(X, y4)

# print(X.shape)
# print(y1.shape)
min30=[]
min60=[]
min90=[]
min120=[]
columns = ['30_min_horizon', '60_min_horizon', '90_min_horizon','120_min_horizon']
indexList=[]
for i in range(1,301):
    fullpath=path+str(i)+'\\weather_data.csv'
    df_test = pd.read_csv(fullpath)
#     print(df_test.columns)
    df_test = df_test.rename(columns={'Time [Mins]':'time','Global CMP22 (vent/cor) [W/m^2]':'CMP22', 'Direct sNIP [W/m^2]':'sNIP', 'Azimuth Angle [degrees]':'Angle', 'Tower Dry Bulb Temp [deg C]':'dryBulbTemp', 'Tower Wet Bulb Temp [deg C]':'wetBulbTemp', 'Tower Dew Point Temp [deg C]':'dewPtTemp', 'Tower RH [%]':'RH', 'Total Cloud Cover [%]':'TCC', 'Peak Wind Speed @ 6ft [m/s]':'windSpeed', 'Station Pressure [mBar]':'pressure', 'Precipitation (Accumulated) [mm]':'rain', 'Snow Depth [cm]':'snowDepth', 'Albedo (CMP11)':'Albedo','Avg Wind Direction @ 6ft [deg from N]':'windDirection'})
    new_columnName = ['time', 'CMP22', 'sNIP', 'Angle', 'dryBulbTemp',
       'wetBulbTemp', 'dewPtTemp', 'RH', 'windSpeed', 'windDirection',
       'pressure', 'rain', 'snowDepth', 'Moisture', 'Albedo', 'TCC','TCC_30min', 'TCC_60min',
       'TCC_90min', 'TCC_120min']
    df_test = df_test.reindex(columns=new_columnName)
    df_test = df_test[df_test.TCC > -1]
#     print(df_test.columns)
#     s_test = df_test['MST']
#     arr=[]
#     print(df_test)
#     for index, val in s_test.items():
#         print(str(val).split(':')[0])
#         arr.append((int(str(val).split(':')[0])*60) + (int(str(val).split(':')[1])))
#     df_test_ = df_test.assign(time = arr)
#     new_columnName = ['DATE (MM/DD)', 'MST', 'time', 'CMP22', 'sNIP', 'Angle', 'dryBulbTemp',
#        'wetBulbTemp', 'dewPtTemp', 'RH', 'windSpeed', 'windDirection',
#        'pressure', 'rain', 'snowDepth', 'Moisture', 'Albedo', 'TCC', 'TCC_30min', 'TCC_60min','TCC_90min','TCC_120min']
#     df_test_ = df_test_.reindex(columns=new_columnName)
#     df_test_ = df_test_.drop(['DATE (MM/DD)', 'MST'], axis=1)
    X_test = df_test.iloc[:, :-4].values
#         y30_test = df_test_.iloc[:, -4].values
#         y60_test = df_test_.iloc[:, -3].values
#         y90_test = df_test_.iloc[:, -2].values
#         y120_test = df_test_.iloc[:, -1].values
#     Y_pred = 'y'+str(count)+'_pred'
#     print(X_test.shape)
    y30_pred = regressor1.predict(X_test)
    y60_pred = regressor2.predict(X_test)
    y90_pred = regressor3.predict(X_test)
    y120_pred = regressor4.predict(X_test)
    
#     print(y30_pred)
    for val in range(len(y30_pred)):
        y30_pred[val] = int(y30_pred[val]) if y30_pred[val]<=100 else 100
    for val in range(len(y60_pred)):
        y60_pred[val] = int(y60_pred[val]) if y60_pred[val]<=100 else 100
    for val in range(len(y90_pred)):
        y90_pred[val] = int(y90_pred[val]) if y90_pred[val]<=100 else 100
    for val in range(len(y120_pred)):
        y120_pred[val] = int(y120_pred[val]) if y120_pred[val]<=100 else 100
#     print(y30_pred)
#     y60_pred = regressor2.predict(X_test)
#     y90_pred = regressor3.predict(X_test)
#     y120_pred = regressor4.predict(X_test)

    df_res_test = pd.DataFrame({'30_min_horizon': y30_pred, '60_min_horizon':y60_pred, '90_min_horizon':y90_pred, '120_min_horizon':y120_pred})
    df_res_test1=df_res_test
    df_res_test1['30_min_horizon'] = df_res_test['30_min_horizon'].astype(int)
    df_res_test1['60_min_horizon'] = df_res_test['60_min_horizon'].astype(int)
    df_res_test1['90_min_horizon'] = df_res_test['90_min_horizon'].astype(int)
    df_res_test1['120_min_horizon'] = df_res_test['120_min_horizon'].astype(int)
    
#     print(df_res_test1.tail(1))
    
    min30.append(df_res_test1.iloc[-1]['30_min_horizon'])
    min60.append(df_res_test1.iloc[-1]['60_min_horizon'])
    min90.append(df_res_test1.iloc[-1]['90_min_horizon'])
    min120.append(df_res_test1.iloc[-1]['120_min_horizon'])
    
    indexList.append(i)
    
    
finalData = {'30_min_horizon':min30, '60_min_horizon':min60, '90_min_horizon':min90, '120_min_horizon':min120}
# index=indexList

finalDF = pd.DataFrame(finalData, index=indexList)
finalDF
# Out:
#      30_min_horizon  60_min_horizon  90_min_horizon  120_min_horizon
# 1               100             100             100              100
# 2                58              63              69               89
# 3               100             100             100              100
# 4                75              80              86              100
# 5                37              43              47               69
# 6                35              42              49               72
# 7                39              47              55               83
# 8                43              50              57               81
# 9                87              91              95              100
# 10               45              51              56               80
# 11              100             100             100              100
# 12              100             100             100              100
# 13               71              77              84              100
# ...

# %%
df6.columns
# Out:
# Index(['time', 'CMP22', 'sNIP', 'Angle', 'dryBulbTemp', 'wetBulbTemp',
#        'dewPtTemp', 'RH', 'windSpeed', 'windDirection', 'pressure', 'rain',
#        'snowDepth', 'Moisture', 'Albedo', 'TCC', 'TCC_30min', 'TCC_60min',
#        'TCC_90min', 'TCC_120min'],
#       dtype='object')

# %%
df_res_test1=df_res_test
df_res_test1['30_min_horizon'] = df_res_test['30_min_horizon'].astype(int)
df_res_test1['30_min_horizon'].dtype
df_res_test1['30_min_horizon'].tail(1)
# Out:
# 354    49
# Name: 30_min_horizon, dtype: int32

# %%
finalDF.to_csv('D:\\Documents\\ML\\shell_dataset\\dataset\\submission.csv')
